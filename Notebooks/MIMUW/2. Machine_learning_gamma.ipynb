# %% [markdown]
# # Maximum Likelihood
#
# ## Optimization Surface
#
# ML Estimator seeks to **best fit the data**. This is the **lowest point at the neg-probability / parameters surface**.

# %%
# @title Run Simulation

N_SAMPLES = 10 # @param {type:"integer"}
N_GRID = 50 # @param {type:"integer"}
mu = 10 # @param {type:"number"}
std = 3 # @param {type:"number"}

import numpy as np
from scipy import stats
import plotly.graph_objects as go

x = np.random.gamma(shape=(mu/std)**2 ,scale=std**2/mu,size=(N_SAMPLES,)) # samples

fn_log_p = lambda mu,std: stats.distributions.gamma.logpdf(np.expand_dims(x,-1), (mu/std)**2, scale=std**2/mu).sum(0)

mu_vals = np.linspace(0.5 * mu, 1.5 * mu, N_GRID)
std_vals = np.linspace(0.5 * std, 1.5 * std, N_GRID)
mu_vals, std_vals = np.meshgrid(mu_vals, std_vals)
logp_vals = fn_log_p(mu_vals.ravel(),std_vals.ravel()) # (N_GRID * N_GRID)
#logp_vals = logp_vals.sum(0) # (, N_GRID * N_GRID)
logp_vals = logp_vals.reshape(N_GRID,N_GRID) # (N_GRID, N_GRID)

fig = go.Figure(
    data=[go.Mesh3d(x=mu_vals.ravel(), y=std_vals.ravel(), z=-logp_vals.ravel(), color='lightpink', opacity=0.50)],
)

fig.update_layout(scene = dict(
                    xaxis_title=r'mu',
                    yaxis_title=r'sigma',
                    zaxis_title=r'logp(data)',
), title=f"negative log-probability of 10 samples from gamma distribution, depending on mu and sigma."
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e73df8c2-a3f2-4af2-9433-ed39ffb904bf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e73df8c2-a3f2-4af2-9433-ed39ffb904bf")) {                    Plotly.newPlot(                        "e73df8c2-a3f2-4af2-9433-ed39ffb904bf",                        [{"color":"lightpink","opacity":0.5,"x":[5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245, ...

# %% [markdown]
# ## Numerical Optimization
#
# Optimization algorithms **may require a good initial guess**.

# %%
# @title Run Optimization

mu_init = 10.0 # @param {type:"number"}
std_init = 2.0 # @param {type:"number"}

from scipy import optimize

optim = optimize.minimize(lambda x: -fn_log_p(x[0],x[1]),x0=(mu_init,std_init))
mu_best,std_best = optim.x
print(f"best mu={mu_best:.3f},best std={std_best:.3f}")
# Out:
# best mu=10.417,best std=3.377

# %% [markdown]
# # Reparametrization
#
# **Transforming parameters** can help for both **enforcing constraings** and **improving convergence**.

# %%
# @title Run Simulation

N_SAMPLES = 100
N_GRID = 50
mu = 10.0
std = 3.0
log_std = np.log(std)

import numpy as np
from scipy import stats

x = np.random.gamma(shape=(mu/std)**2 ,scale=std**2/mu,size=(N_SAMPLES,)) # samples

fn_log_p = lambda mu,log_std: stats.distributions.gamma.logpdf(np.expand_dims(x,-1), (mu/np.exp(log_std))**2, scale=np.exp(log_std)**2/mu).sum(0)

mu_vals = np.linspace(0.5*mu, 1.5*mu, N_GRID)
log_std_vals = np.linspace(log_std-0.5, log_std+0.5, N_GRID)
mu_vals, log_std_vals = np.meshgrid(mu_vals, log_std_vals)
logp_vals = fn_log_p(mu_vals.ravel(),log_std_vals.ravel()) # (N_GRID * N_GRID)
#logp_vals = logp_vals.sum(0) # (, N_GRID * N_GRID)
logp_vals = logp_vals.reshape(N_GRID,N_GRID) # (N_GRID, N_GRID)

fig = go.Figure(
    data=[go.Mesh3d(x=mu_vals.ravel(), y=log_std_vals.ravel(), z=-logp_vals.ravel(), color='lightpink', opacity=0.50)],
)

fig.update_layout(scene = dict(
                    xaxis_title=r'mu',
                    yaxis_title=r'log-sigma',
                    zaxis_title=r'logp(data)',
), title=f"negative log-probability of 10 samples from gamma distribution, depending on mu and log-sigma."
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1db0c393-4d03-4761-996e-055d0ec0e761" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1db0c393-4d03-4761-996e-055d0ec0e761")) {                    Plotly.newPlot(                        "1db0c393-4d03-4761-996e-055d0ec0e761",                        [{"color":"lightpink","opacity":0.5,"x":[5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245,13.36734693877551,13.571428571428571,13.775510204081632,13.979591836734695,14.183673469387756,14.387755102040817,14.591836734693878,14.795918367346939,15.0,5.0,5.204081632653061,5.408163265306122,5.612244897959184,5.816326530612245,6.020408163265306,6.224489795918368,6.428571428571429,6.63265306122449,6.836734693877551,7.040816326530612,7.244897959183674,7.448979591836735,7.653061224489796,7.857142857142858,8.061224489795919,8.26530612244898,8.46938775510204,8.673469387755102,8.877551020408163,9.081632653061224,9.285714285714285,9.489795918367347,9.693877551020408,9.89795918367347,10.10204081632653,10.306122448979592,10.510204081632654,10.714285714285715,10.918367346938776,11.122448979591837,11.326530612244898,11.53061224489796,11.73469387755102,11.938775510204081,12.142857142857142,12.346938775510203,12.551020408163264,12.755102040816327,12.959183673469388,13.16326530612245, ...

# %%
# @title Run Optimization

mu_init = 10.0 # @param {type:"number"}
log_std_init = 1.0 # @param {type:"number"}

from scipy import optimize

optim = optimize.minimize(lambda x: -fn_log_p(x[0],x[1]),x0=(mu_init,log_std_init))
mu_best,log_std_best = optim.x
std_best = np.exp(log_std_best)
print(f"best mu={mu_best:.3f},best std={std_best:.3f}")
# Out:
# best mu=10.010,best std=2.939
